# %%
import torch
import pathlib

# %%
celeba = "C:/Users/blais/Documents/ML/data/celeba/"

# %%
import torchvision

# %%
celeba_dataset = torchvision.datasets.CelebA(celeba,split='train',target_type='attr',download=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 celeba_dataset = torchvision.datasets.CelebA(celeba,split='train',target_type='attr',download=False)
#
# File c:\Users\blais\Documents\ML\venv2\lib\site-packages\torchvision\datasets\celeba.py:88, in CelebA.__init__(self, root, split, target_type, transform, target_transform, download)
#      85     self.download()
#      87 if not self._check_integrity():
# ---> 88     raise RuntimeError("Dataset not found or corrupted. You can use download=True to download it")
#      90 split_map = {
#      91     "train": 0,
#      92     "valid": 1,
#      93     "test": 2,
#      94     "all": None,
#      95 }
#      96 split_ = split_map[
#      97     verify_str_arg(
#      98         split.lower() if isinstance(split, str) else split,
#    (...)
#     101     )
#     102 ]
#
# ...

# %%
mnist_path = "C:/Users/blais/Documents/ML/data/mnist/"

# %%
mnist_dataset = torchvision.datasets.MNIST(mnist_path,'train',download=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.04MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 369kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 2.96MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<?, ?B/s]

# %%
assert isinstance(mnist_dataset, torch.utils.data.Dataset)

# %%
example = next(iter(mnist_dataset))

# %%
print(example)
# Out:
# (<PIL.Image.Image image mode=L size=28x28 at 0x271AF271030>, 5)

# %%
from itertools import islice
import matplotlib.pyplot as plt

# %%
s_data = islice(mnist_dataset,10)

# %%
fig, ax = plt.subplots(2,5,figsize=(15,6))

for i in range(2):
    for j in range(5):
        ax[i,j].set_xticks([]); ax[i,j].set_yticks([])
        image,label = next(s_data)
        ax[i,j].imshow(image,cmap='gray_r')
        ax[i,j].set_title(f'{label}',size=15)
plt.show()
