# %% [markdown]
# **Forecasting Using a Sequence-to-Sequence Model:**
# - Instead of training the model to forecast the next 14 values only at the very last timestep, we can train it to forecast the next 14 values at each and every timestep. In otherwords, we can turn this sequence-to-vector RNN into a sequence-to-sequence RNN. The advantage being that the loss will contain a term for the output of the RNN at each and every timestep, not just the output at the last timestep.
# - Implying that there will be more error gradients flowing through the model, and they won't have to flow through time as much since they will come from the output of each timestep, not just the last one
# - To be clear, at timestep 0, the model will output a vector containing the forecasts for timesteps 1 to 14, then, at timestep 1 the forecast from timesteps 2 to 15, and so on. The targets are sequences of consecutive windows, shifted by one timestep at each timestep. The target isn't a vector anymore, but a sequence of the same length as the inputs, containing a 14-dimensional vector at each step.

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, Subset
import matplotlib.pyplot as plt
from utils.fetch_data import fetch_timeseries_data
from utils.load_data import TimeSeriesDataset
import utils.train_model as train_mod
import importlib
importlib.reload(train_mod)
train_oned = train_mod.train_oned
import importlib
import utils.fetch_data as fetch_data
importlib.reload(fetch_data)
create_splits = fetch_data.create_splits
create_oned_chunks = fetch_data.create_oned_chunks
from utils.early_stopping import EarlyStopping

# %%
importlib.reload(train_mod)
train_oned2 = train_mod.train_oned2

# %% [markdown]
# Get the data:

# %%
df = fetch_timeseries_data()

# %%
df['2019-03':'2019-05'].plot(grid=True, marker='.',figsize=(10,3.5))
plt.show()

# %%
torch.manual_seed(1)

# %%
rail_train, rail_valid, rail_test = create_splits(df)

# %%
rail_train
# Out:
# date
# 2016-01-01    0.319835
# 2016-01-02    0.365509
# 2016-01-03    0.287661
# 2016-01-04    0.703185
# 2016-01-05    0.727716
#                 ...
# 2018-12-27    0.453029
# 2018-12-28    0.493961
# 2018-12-29    0.307105
# 2018-12-30    0.265310
# 2018-12-31    0.386058
# Name: rail, Length: 1096, dtype: float64

# %%
rail_train.values
# Out:
# array([0.319835, 0.365509, 0.287661, ..., 0.307105, 0.26531 , 0.386058],
#       shape=(1096,))

# %%
train_x_chunks = [rail_train.values.tolist()[i:i+56] for i in range(len(rail_train.values.tolist())-56-14+1)]

# %%
torch.tensor(train_x_chunks).shape
# Out:
# torch.Size([1027, 56])

# %%
train_y_chunks = []

for i in range(len(rail_train.values.tolist())-56-14+1):
    train_y_chunks.append([rail_train.values.tolist()[i+j+1:i+j+1+14] for j in range(56)])

# %%
torch.tensor(train_y_chunks).shape
# Out:
# torch.Size([1027, 56, 14])

# %%
torch.tensor(train_x_chunks)[1026]
# Out:
# tensor([0.7936, 0.7959, 0.8028, 0.7778, 0.4355, 0.3152, 0.7661, 0.7850, 0.7764,
#         0.7983, 0.7543, 0.4285, 0.2913, 0.7702, 0.7647, 0.7832, 0.7973, 0.7514,
#         0.3857, 0.3047, 0.6522, 0.7692, 0.7662, 0.7649, 0.7832, 0.4537, 0.3160,
#         0.7402, 0.7415, 0.6054, 0.1965, 0.3932, 0.3480, 0.2470, 0.6471, 0.7424,
#         0.7498, 0.7646, 0.7605, 0.3591, 0.2852, 0.7311, 0.7457, 0.7370, 0.7571,
#         0.7314, 0.3997, 0.2917, 0.7065, 0.7311, 0.7271, 0.7380, 0.7242, 0.4251,
#         0.3093, 0.6680])

# %%
torch.tensor(train_y_chunks)[1026,0,:]
# Out:
# tensor([0.7959, 0.8028, 0.7778, 0.4355, 0.3152, 0.7661, 0.7850, 0.7764, 0.7983,
#         0.7543, 0.4285, 0.2913, 0.7702, 0.7647])

# %%
torch.tensor(train_y_chunks)[1026,54,:]
# Out:
# tensor([0.6680, 0.7019, 0.7008, 0.6820, 0.6335, 0.3394, 0.2601, 0.2793, 0.1280,
#         0.4120, 0.4530, 0.4940, 0.3071, 0.2653])

# %%
train_x_chunks = torch.tensor(train_x_chunks)
train_y_chunks = torch.tensor(train_y_chunks)

# %% [markdown]
# Done it => successfully come up with a method of forming tensors for sequence to sequence timeseries training.

# %% [markdown]
# need to do it for the validation and test sets now:

# %%
valid_x_chunks = torch.tensor([rail_valid.values.tolist()[i:i+56] for i in range(len(rail_valid.values.tolist())-56-14+1)])
valid_x_chunks.shape
# Out:
# torch.Size([82, 56])

# %% [markdown]
# - essentially, what we've created with valid_x_chunks an array of shape: batch_size x seq_length. We iterated through the entire dataset, generating sequences of length 56, and making sure not to go past the point where we can't perfectly form sequences of length 56 - hence justifying the (-56 from the range). Also, need to ensure that the final 14 values to be predicted (14 future values since we are building a model to forecast 14 timesteps ahead in oneshot - do not appear in the last batch's x values - so as to avoid data leakage).
# - Now using that context and information we create the y chunks as well: we ensure we have the same batch size as the original x chunks, so we iterate through the same length of inputs. then -> remember that for the y chunks we are trying to create chunks of shape: (batch_size, sequence_length, 14 timesteps). so for each timestep we lool through, we need to come up with a tensor of shape [56,14]. so for each timestep - we have another internal loop, looping through 56 values, and each time we do so, get the next 14 future values

# %%
valid_y_chunks = []

# think of this loop 
for i in range(len(rail_valid.values.tolist())-56-14+1):
    valid_y_chunks.append([rail_valid.values.tolist()[i+j+1:i+j+1+14] for j in range(56)])

# %%
valid_y_chunks = torch.tensor(valid_y_chunks)
valid_y_chunks.shape
# Out:
# torch.Size([82, 56, 14])

# %% [markdown]
# Do it for the test set:

# %%
test_x_chunks = torch.tensor([rail_test.values.tolist()[i:i+56] for i in range(len(rail_test.values.tolist())-56-14+1)])
test_x_chunks.shape
# Out:
# torch.Size([2215, 56])

# %%
test_y_chunks = []

for i in range(len(rail_test.values.tolist())-56-14+1):
    test_y_chunks.append([rail_test.values.tolist()[i+j+1:i+j+1+14] for j in range(56)])

test_y_chunks = torch.tensor(test_y_chunks)
test_y_chunks.shape
# Out:
# torch.Size([2215, 56, 14])

# %% [markdown]
# Batch the data:

# %%
train_x_chunks.shape, train_y_chunks.shape
# Out:
# (torch.Size([1027, 56]), torch.Size([1027, 56, 14]))

# %%
class SequenceDataset(Dataset):
    def __init__(self, x_chunks, y_chunks):
        self.x_chunks = x_chunks.unsqueeze(2)
        self.y_chunks = y_chunks
    def __len__(self):
        return self.x_chunks.shape[0]
    
    def __getitem__(self, index):
        c_x = self.x_chunks[index]
        c_y = self.y_chunks[index]
        return c_x, c_y

# %%
train_ds = SequenceDataset(train_x_chunks, train_y_chunks)
val_ds = SequenceDataset(valid_x_chunks, valid_y_chunks)
test_ds = SequenceDataset(test_x_chunks, test_y_chunks)

# %%
train_dl = DataLoader(train_ds, batch_size=128, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=128)
test_dl = DataLoader(test_ds, batch_size=1024)

# %% [markdown]
# Now Build the model:

# %%
class Seq2SeqUnivar(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.rnn = nn.LSTM(input_size, hidden_size, batch_first=True, num_layers=1)
        self.linear = nn.Linear(hidden_size, 14)
    def forward(self, input):
        out, (_, _) = self.rnn(input)
        return self.linear(out)

# %%
device = torch.device("mps" if torch.mps.is_available() else "cpu")

# %%
torch.manual_seed(1)
seq2seq = Seq2SeqUnivar(1,32).to(device)

# %%
# optimizer = torch.optim.SGD(seq2seq.parameters(), lr=0.02, momentum=0.95, nesterov=True)
optimizer = torch.optim.AdamW(seq2seq.parameters(), lr=0.001)
criterion = nn.HuberLoss(reduction='sum')
early_stopper = EarlyStopping(patience=50, checkpoint_path = 'seq2seq.pt', restore_best_weights=True, verbose=True)
#cheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.009, epochs=500, steps_per_epoch=len(rail_train_dl))
scheduler2 = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.85)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',patience=5)

# %%
t_loss, v_loss = train_oned2(500, seq2seq, train_dl, val_dl, device, criterion, optimizer, early_stopper, performance_scheduler=scheduler,other_scheduler=None)
# Out:
# Epoch: 1| Train loss: 185.4847| Val loss: 150.3638
# Metric improved to 150.3638. Checkpoint saved at epoch 0
# Epoch: 2| Train loss: 164.7680| Val loss: 131.1478
# Metric improved to 131.1478. Checkpoint saved at epoch 1
# Epoch: 3| Train loss: 142.0518| Val loss: 106.7283
# Metric improved to 106.7283. Checkpoint saved at epoch 2
# Epoch: 4| Train loss: 109.8175| Val loss: 68.2214
# Metric improved to 68.2214. Checkpoint saved at epoch 3
# Epoch: 5| Train loss: 59.7066| Val loss: 33.1999
# Metric improved to 33.1999. Checkpoint saved at epoch 4
# Epoch: 6| Train loss: 33.5716| Val loss: 29.1194
# Metric improved to 29.1194. Checkpoint saved at epoch 5
# Epoch: 7| Train loss: 23.5130| Val loss: 19.3826
# Metric improved to 19.3826. Checkpoint saved at epoch 6
# Epoch: 8| Train loss: 19.5776| Val loss: 18.2485
# Metric improved to 18.2485. Checkpoint saved at epoch 7
# Epoch: 9| Train loss: 19.0207| Val loss: 18.5993
# No improvement for 1 epoch(s)
# Epoch: 10| Train loss: 18.5259| Val loss: 18.4979
# No improvement for 2 epoch(s)
# Epoch: 11| Train loss: 18.1244| Val loss: 18.0390
# Metric improved to 18.0390. Checkpoint saved at epoch 10
# Epoch: 12| Train loss: 17.8590| Val loss: 17.8389
# Metric improved to 17.8389. Checkpoint saved at epoch 11
# Epoch: 13| Train loss: 17.6333| Val loss: 17.7547
# Metric improved to 17.7547. Checkpoint saved at epoch 12
# Epoch: 14| Train loss: 17.4243| Val loss: 17.5773
# Metric improved to 17.5773. Checkpoint saved at epoch 13
# Epoch: 15| Train loss: 17.2267| Val loss: 17.4022
# Metric improved to 17.4022. Checkpoint saved at epoch 14
# Epoch: 16| Train loss: 17.0357| Val loss: 17.2665
# Metric improved to 17.2665. Checkpoint saved at epoch 15
# Epoch: 17| Train loss: 16.8457| Val loss: 17.1211
# Metric improved to 17.1211. Checkpoint saved at epoch 16
# Epoch: 18| Train loss: 16.6540| Val loss: 16.9808
# Metric improved to 16.9808. Checkpoint saved at epoch 17
# Epoch: 19| Train loss: 16.4601| Val loss: 16.8050
# Metric improved to 16.8050. Checkpoint saved at epoch 18
# Epoch: 20| Train loss: 16.2637| Val loss: 16.6440
# Metric improved to 16.6440. Checkpoint saved at epoch 19
# Epoch: 21| Train loss: 16.0648| Val loss: 16.5324
# Metric improved to 16.5324. Checkpoint saved at epoch 20
# Epoch: 22| Train loss: 15.8712| Val loss: 16.3729
# Metric improved to 16.3729. Checkpoint saved at epoch 21
# Epoch: 23| Train loss: 15.6888| Val loss: 16.2643
# Metric improved to 16.2643. Checkpoint saved at epoch 22
# Epoch: 24| Train loss: 15.5236| Val loss: 16.2364
# Metric improved to 16.2364. Checkpoint saved at epoch 23
# Epoch: 25| Train loss: 15.3735| Val loss: 16.1067
# Metric improved to 16.1067. Checkpoint saved at epoch 24
# Epoch: 26| Train loss: 15.2392| Val loss: 15.9991
# Metric improved to 15.9991. Checkpoint saved at epoch 25
# Epoch: 27| Train loss: 15.1193| Val loss: 16.0749
# No improvement for 1 epoch(s)
# Epoch: 28| Train loss: 15.0113| Val loss: 15.7387
# Metric improved to 15.7387. Checkpoint saved at epoch 27
# Epoch: 29| Train loss: 14.9222| Val loss: 15.9332
# No improvement for 1 epoch(s)
# Epoch: 30| Train loss: 14.8164| Val loss: 15.8198
# No improvement for 2 epoch(s)
# Epoch: 31| Train loss: 14.7168| Val loss: 15.6489
# Metric improved to 15.6489. Checkpoint saved at epoch 30
# Epoch: 32| Train loss: 14.6270| Val loss: 15.7133
# No improvement for 1 epoch(s)
# Epoch: 33| Train loss: 14.5423| Val loss: 15.5577
# Metric improved to 15.5577. Checkpoint saved at epoch 32
# Epoch: 34| Train loss: 14.4554| Val loss: 15.5052
# Metric improved to 15.5052. Checkpoint saved at epoch 33
# Epoch: 35| Train loss: 14.3734| Val loss: 15.3447
# Metric improved to 15.3447. Checkpoint saved at epoch 34
# Epoch: 36| Train loss: 14.2930| Val loss: 15.4576
# No improvement for 1 epoch(s)
# Epoch: 37| Train loss: 14.2099| Val loss: 15.2574
# Metric improved to 15.2574. Checkpoint saved at epoch 36
# Epoch: 38| Train loss: 14.1261| Val loss: 15.2409
# Metric improved to 15.2409. Checkpoint saved at epoch 37
# Epoch: 39| Train loss: 14.0458| Val loss: 15.1933
# Metric improved to 15.1933. Checkpoint saved at epoch 38
# Epoch: 40| Train loss: 13.9587| Val loss: 15.1551
# Metric improved to 15.1551. Checkpoint saved at epoch 39
# Epoch: 41| Train loss: 13.8707| Val loss: 15.0132
# Metric improved to 15.0132. Checkpoint saved at epoch 40
# Epoch: 42| Train loss: 13.7804| Val loss: 14.8370
# Metric improved to 14.8370. Checkpoint saved at epoch 41
# Epoch: 43| Train loss: 13.6867| Val loss: 14.8574
# No improvement for 1 epoch(s)
# Epoch: 44| Train loss: 13.5963| Val loss: 14.9937
# No improvement for 2 epoch(s)
# Epoch: 45| Train loss: 13.5222| Val loss: 14.7918
# Metric improved to 14.7918. Checkpoint saved at epoch 44
# Epoch: 46| Train loss: 13.4106| Val loss: 14.6512
# Metric improved to 14.6512. Checkpoint saved at epoch 45
# Epoch: 47| Train loss: 13.3084| Val loss: 14.4853
# Metric improved to 14.4853. Checkpoint saved at epoch 46
# Epoch: 48| Train loss: 13.2049| Val loss: 14.3746
# Metric improved to 14.3746. Checkpoint saved at epoch 47
# Epoch: 49| Train loss: 13.1007| Val loss: 14.3337
# Metric improved to 14.3337. Checkpoint saved at epoch 48
# Epoch: 50| Train loss: 12.9867| Val loss: 14.1540
# Metric improved to 14.1540. Checkpoint saved at epoch 49
# Epoch: 51| Train loss: 12.8623| Val loss: 13.9880
# Metric improved to 13.9880. Checkpoint saved at epoch 50
# Epoch: 52| Train loss: 12.7242| Val loss: 13.8109
# Metric improved to 13.8109. Checkpoint saved at epoch 51
# Epoch: 53| Train loss: 12.5696| Val loss: 13.6471
# Metric improved to 13.6471. Checkpoint saved at epoch 52
# Epoch: 54| Train loss: 12.3917| Val loss: 13.4139
# Metric improved to 13.4139. Checkpoint saved at epoch 53
# Epoch: 55| Train loss: 12.1785| Val loss: 13.1621
# Metric improved to 13.1621. Checkpoint saved at epoch 54
# Epoch: 56| Train loss: 11.9172| Val loss: 12.8763
# Metric improved to 12.8763. Checkpoint saved at epoch 55
# Epoch: 57| Train loss: 11.5862| Val loss: 12.4388
# Metric improved to 12.4388. Checkpoint saved at epoch 56
# Epoch: 58| Train loss: 11.1585| Val loss: 11.9294
# Metric improved to 11.9294. Checkpoint saved at epoch 57
# Epoch: 59| Train loss: 10.6488| Val loss: 11.3879
# Metric improved to 11.3879. Checkpoint saved at epoch 58
# Epoch: 60| Train loss: 10.0983| Val loss: 10.7158
# Metric improved to 10.7158. Checkpoint saved at epoch 59
# Epoch: 61| Train loss: 9.5235| Val loss: 10.1046
# Metric improved to 10.1046. Checkpoint saved at epoch 60
# Epoch: 62| Train loss: 8.9979| Val loss: 9.5694
# Metric improved to 9.5694. Checkpoint saved at epoch 61
# Epoch: 63| Train loss: 8.5682| Val loss: 9.1142
# Metric improved to 9.1142. Checkpoint saved at epoch 62
# Epoch: 64| Train loss: 8.2367| Val loss: 8.8655
# Metric improved to 8.8655. Checkpoint saved at epoch 63
# Epoch: 65| Train loss: 7.9855| Val loss: 8.5655
# Metric improved to 8.5655. Checkpoint saved at epoch 64
# Epoch: 66| Train loss: 7.7943| Val loss: 8.4421
# Metric improved to 8.4421. Checkpoint saved at epoch 65
# Epoch: 67| Train loss: 7.6474| Val loss: 8.2342
# Metric improved to 8.2342. Checkpoint saved at epoch 66
# Epoch: 68| Train loss: 7.5294| Val loss: 8.2185
# Metric improved to 8.2185. Checkpoint saved at epoch 67
# Epoch: 69| Train loss: 7.4306| Val loss: 8.1179
# Metric improved to 8.1179. Checkpoint saved at epoch 68
# Epoch: 70| Train loss: 7.3462| Val loss: 8.0280
# Metric improved to 8.0280. Checkpoint saved at epoch 69
# Epoch: 71| Train loss: 7.2709| Val loss: 7.9636
# Metric improved to 7.9636. Checkpoint saved at epoch 70
# Epoch: 72| Train loss: 7.2040| Val loss: 7.8698
# Metric improved to 7.8698. Checkpoint saved at epoch 71
# Epoch: 73| Train loss: 7.1421| Val loss: 7.8409
# Metric improved to 7.8409. Checkpoint saved at epoch 72
# Epoch: 74| Train loss: 7.0802| Val loss: 7.8093
# Metric improved to 7.8093. Checkpoint saved at epoch 73
# Epoch: 75| Train loss: 7.0239| Val loss: 7.8115
# No improvement for 1 epoch(s)
# Epoch: 76| Train loss: 6.9713| Val loss: 7.6928
# Metric improved to 7.6928. Checkpoint saved at epoch 75
# Epoch: 77| Train loss: 6.9131| Val loss: 7.6384
# Metric improved to 7.6384. Checkpoint saved at epoch 76
# Epoch: 78| Train loss: 6.8605| Val loss: 7.5914
# Metric improved to 7.5914. Checkpoint saved at epoch 77
# Epoch: 79| Train loss: 6.8074| Val loss: 7.5935
# No improvement for 1 epoch(s)
# Epoch: 80| Train loss: 6.7573| Val loss: 7.4165
# Metric improved to 7.4165. Checkpoint saved at epoch 79
# Epoch: 81| Train loss: 6.7062| Val loss: 7.4533
# No improvement for 1 epoch(s)
# Epoch: 82| Train loss: 6.6522| Val loss: 7.3456
# Metric improved to 7.3456. Checkpoint saved at epoch 81
# Epoch: 83| Train loss: 6.5985| Val loss: 7.3966
# No improvement for 1 epoch(s)
# Epoch: 84| Train loss: 6.5401| Val loss: 7.2660
# Metric improved to 7.2660. Checkpoint saved at epoch 83
# Epoch: 85| Train loss: 6.4821| Val loss: 7.2410
# Metric improved to 7.2410. Checkpoint saved at epoch 84
# Epoch: 86| Train loss: 6.4200| Val loss: 7.1045
# Metric improved to 7.1045. Checkpoint saved at epoch 85
# Epoch: 87| Train loss: 6.3565| Val loss: 7.0398
# Metric improved to 7.0398. Checkpoint saved at epoch 86
# Epoch: 88| Train loss: 6.2893| Val loss: 6.9694
# Metric improved to 6.9694. Checkpoint saved at epoch 87
# Epoch: 89| Train loss: 6.2190| Val loss: 6.8992
# Metric improved to 6.8992. Checkpoint saved at epoch 88
# Epoch: 90| Train loss: 6.1457| Val loss: 6.8048
# Metric improved to 6.8048. Checkpoint saved at epoch 89
# Epoch: 91| Train loss: 6.0678| Val loss: 6.6936
# Metric improved to 6.6936. Checkpoint saved at epoch 90
# Epoch: 92| Train loss: 5.9876| Val loss: 6.6291
# Metric improved to 6.6291. Checkpoint saved at epoch 91
# Epoch: 93| Train loss: 5.9012| Val loss: 6.5231
# Metric improved to 6.5231. Checkpoint saved at epoch 92
# Epoch: 94| Train loss: 5.8138| Val loss: 6.4422
# Metric improved to 6.4422. Checkpoint saved at epoch 93
# Epoch: 95| Train loss: 5.7223| Val loss: 6.3067
# Metric improved to 6.3067. Checkpoint saved at epoch 94
# Epoch: 96| Train loss: 5.6283| Val loss: 6.1761
# Metric improved to 6.1761. Checkpoint saved at epoch 95
# Epoch: 97| Train loss: 5.5392| Val loss: 6.0836
# Metric improved to 6.0836. Checkpoint saved at epoch 96
# Epoch: 98| Train loss: 5.4404| Val loss: 5.9529
# Metric improved to 5.9529. Checkpoint saved at epoch 97
# Epoch: 99| Train loss: 5.3434| Val loss: 5.7950
# Metric improved to 5.7950. Checkpoint saved at epoch 98
# Epoch: 100| Train loss: 5.2499| Val loss: 5.7066
# Metric improved to 5.7066. Checkpoint saved at epoch 99
# Epoch: 101| Train loss: 5.1596| Val loss: 5.5881
# Metric improved to 5.5881. Checkpoint saved at epoch 100
# Epoch: 102| Train loss: 5.0677| Val loss: 5.5034
# Metric improved to 5.5034. Checkpoint saved at epoch 101
# Epoch: 103| Train loss: 4.9791| Val loss: 5.3021
# Metric improved to 5.3021. Checkpoint saved at epoch 102
# Epoch: 104| Train loss: 4.8926| Val loss: 5.3487
# No improvement for 1 epoch(s)
# Epoch: 105| Train loss: 4.8159| Val loss: 5.1685
# Metric improved to 5.1685. Checkpoint saved at epoch 104
# Epoch: 106| Train loss: 4.7353| Val loss: 5.2136
# No improvement for 1 epoch(s)
# Epoch: 107| Train loss: 4.6649| Val loss: 4.9683
# Metric improved to 4.9683. Checkpoint saved at epoch 106
# Epoch: 108| Train loss: 4.6126| Val loss: 4.9347
# Metric improved to 4.9347. Checkpoint saved at epoch 107
# Epoch: 109| Train loss: 4.5348| Val loss: 4.7927
# Metric improved to 4.7927. Checkpoint saved at epoch 108
# Epoch: 110| Train loss: 4.4689| Val loss: 4.9146
# No improvement for 1 epoch(s)
# Epoch: 111| Train loss: 4.4194| Val loss: 4.7238
# Metric improved to 4.7238. Checkpoint saved at epoch 110
# Epoch: 112| Train loss: 4.3685| Val loss: 4.7444
# No improvement for 1 epoch(s)
# Epoch: 113| Train loss: 4.3300| Val loss: 4.6297
# Metric improved to 4.6297. Checkpoint saved at epoch 112
# Epoch: 114| Train loss: 4.2925| Val loss: 4.5596
# Metric improved to 4.5596. Checkpoint saved at epoch 113
# Epoch: 115| Train loss: 4.2638| Val loss: 4.5568
# Metric improved to 4.5568. Checkpoint saved at epoch 114
# Epoch: 116| Train loss: 4.2344| Val loss: 4.5036
# Metric improved to 4.5036. Checkpoint saved at epoch 115
# Epoch: 117| Train loss: 4.2109| Val loss: 4.4767
# Metric improved to 4.4767. Checkpoint saved at epoch 116
# Epoch: 118| Train loss: 4.1897| Val loss: 4.4874
# No improvement for 1 epoch(s)
# Epoch: 119| Train loss: 4.1618| Val loss: 4.4650
# Metric improved to 4.4650. Checkpoint saved at epoch 118
# Epoch: 120| Train loss: 4.1437| Val loss: 4.4857
# No improvement for 1 epoch(s)
# Epoch: 121| Train loss: 4.1250| Val loss: 4.3770
# Metric improved to 4.3770. Checkpoint saved at epoch 120
# Epoch: 122| Train loss: 4.1067| Val loss: 4.3783
# No improvement for 1 epoch(s)
# Epoch: 123| Train loss: 4.0869| Val loss: 4.3342
# Metric improved to 4.3342. Checkpoint saved at epoch 122
# Epoch: 124| Train loss: 4.0676| Val loss: 4.3467
# No improvement for 1 epoch(s)
# Epoch: 125| Train loss: 4.0486| Val loss: 4.2846
# Metric improved to 4.2846. Checkpoint saved at epoch 124
# Epoch: 126| Train loss: 4.0332| Val loss: 4.3192
# No improvement for 1 epoch(s)
# Epoch: 127| Train loss: 4.0155| Val loss: 4.3345
# No improvement for 2 epoch(s)
# Epoch: 128| Train loss: 4.0016| Val loss: 4.2414
# Metric improved to 4.2414. Checkpoint saved at epoch 127
# Epoch: 129| Train loss: 3.9844| Val loss: 4.2754
# No improvement for 1 epoch(s)
# Epoch: 130| Train loss: 3.9700| Val loss: 4.2208
# Metric improved to 4.2208. Checkpoint saved at epoch 129
# Epoch: 131| Train loss: 3.9607| Val loss: 4.2970
# No improvement for 1 epoch(s)
# Epoch: 132| Train loss: 3.9410| Val loss: 4.1480
# Metric improved to 4.1480. Checkpoint saved at epoch 131
# Epoch: 133| Train loss: 3.9281| Val loss: 4.2217
# No improvement for 1 epoch(s)
# Epoch: 134| Train loss: 3.9111| Val loss: 4.1250
# Metric improved to 4.1250. Checkpoint saved at epoch 133
# Epoch: 135| Train loss: 3.8979| Val loss: 4.1492
# No improvement for 1 epoch(s)
# Epoch: 136| Train loss: 3.8847| Val loss: 4.1349
# No improvement for 2 epoch(s)
# Epoch: 137| Train loss: 3.8674| Val loss: 4.1038
# Metric improved to 4.1038. Checkpoint saved at epoch 136
# Epoch: 138| Train loss: 3.8560| Val loss: 4.0939
# Metric improved to 4.0939. Checkpoint saved at epoch 137
# Epoch: 139| Train loss: 3.8401| Val loss: 4.0969
# No improvement for 1 epoch(s)
# Epoch: 140| Train loss: 3.8284| Val loss: 4.0786
# Metric improved to 4.0786. Checkpoint saved at epoch 139
# Epoch: 141| Train loss: 3.8170| Val loss: 4.0893
# No improvement for 1 epoch(s)
# Epoch: 142| Train loss: 3.8011| Val loss: 4.0279
# Metric improved to 4.0279. Checkpoint saved at epoch 141
# Epoch: 143| Train loss: 3.7907| Val loss: 4.0706
# No improvement for 1 epoch(s)
# Epoch: 144| Train loss: 3.7769| Val loss: 4.0097
# Metric improved to 4.0097. Checkpoint saved at epoch 143
# Epoch: 145| Train loss: 3.7646| Val loss: 4.0682
# No improvement for 1 epoch(s)
# Epoch: 146| Train loss: 3.7525| Val loss: 4.0738
# No improvement for 2 epoch(s)
# Epoch: 147| Train loss: 3.7455| Val loss: 4.0976
# No improvement for 3 epoch(s)
# Epoch: 148| Train loss: 3.7332| Val loss: 4.0470
# No improvement for 4 epoch(s)
# Epoch: 149| Train loss: 3.7197| Val loss: 3.9714
# Metric improved to 3.9714. Checkpoint saved at epoch 148
# Epoch: 150| Train loss: 3.7062| Val loss: 4.0163
# No improvement for 1 epoch(s)
# Epoch: 151| Train loss: 3.6942| Val loss: 3.9333
# Metric improved to 3.9333. Checkpoint saved at epoch 150
# Epoch: 152| Train loss: 3.6814| Val loss: 4.0157
# No improvement for 1 epoch(s)
# Epoch: 153| Train loss: 3.6717| Val loss: 3.9139
# Metric improved to 3.9139. Checkpoint saved at epoch 152
# Epoch: 154| Train loss: 3.6632| Val loss: 3.9289
# No improvement for 1 epoch(s)
# Epoch: 155| Train loss: 3.6462| Val loss: 3.9179
# No improvement for 2 epoch(s)
# Epoch: 156| Train loss: 3.6333| Val loss: 3.9268
# No improvement for 3 epoch(s)
# Epoch: 157| Train loss: 3.6227| Val loss: 3.9121
# Metric improved to 3.9121. Checkpoint saved at epoch 156
# Epoch: 158| Train loss: 3.6126| Val loss: 3.9421
# No improvement for 1 epoch(s)
# Epoch: 159| Train loss: 3.6020| Val loss: 3.8953
# Metric improved to 3.8953. Checkpoint saved at epoch 158
# Epoch: 160| Train loss: 3.5925| Val loss: 3.9563
# No improvement for 1 epoch(s)
# Epoch: 161| Train loss: 3.5881| Val loss: 3.8890
# Metric improved to 3.8890. Checkpoint saved at epoch 160
# Epoch: 162| Train loss: 3.5726| Val loss: 3.8889
# Metric improved to 3.8889. Checkpoint saved at epoch 161
# Epoch: 163| Train loss: 3.5594| Val loss: 3.8277
# Metric improved to 3.8277. Checkpoint saved at epoch 162
# Epoch: 164| Train loss: 3.5563| Val loss: 3.8592
# No improvement for 1 epoch(s)
# Epoch: 165| Train loss: 3.5456| Val loss: 3.7589
# Metric improved to 3.7589. Checkpoint saved at epoch 164
# Epoch: 166| Train loss: 3.5351| Val loss: 3.7470
# Metric improved to 3.7470. Checkpoint saved at epoch 165
# Epoch: 167| Train loss: 3.5247| Val loss: 3.7548
# No improvement for 1 epoch(s)
# Epoch: 168| Train loss: 3.5076| Val loss: 3.7844
# No improvement for 2 epoch(s)
# Epoch: 169| Train loss: 3.4964| Val loss: 3.7507
# No improvement for 3 epoch(s)
# Epoch: 170| Train loss: 3.4880| Val loss: 3.7610
# No improvement for 4 epoch(s)
# Epoch: 171| Train loss: 3.4768| Val loss: 3.7957
# No improvement for 5 epoch(s)
# Epoch: 172| Train loss: 3.4673| Val loss: 3.7127
# Metric improved to 3.7127. Checkpoint saved at epoch 171
# Epoch: 173| Train loss: 3.4639| Val loss: 3.7843
# No improvement for 1 epoch(s)
# Epoch: 174| Train loss: 3.4556| Val loss: 3.7689
# No improvement for 2 epoch(s)
# Epoch: 175| Train loss: 3.4477| Val loss: 3.7491
# No improvement for 3 epoch(s)
# Epoch: 176| Train loss: 3.4415| Val loss: 3.7657
# No improvement for 4 epoch(s)
# Epoch: 177| Train loss: 3.4324| Val loss: 3.7955
# No improvement for 5 epoch(s)
# Epoch: 178| Train loss: 3.4215| Val loss: 3.6516
# Metric improved to 3.6516. Checkpoint saved at epoch 177
# Epoch: 179| Train loss: 3.3996| Val loss: 3.6615
# No improvement for 1 epoch(s)
# Epoch: 180| Train loss: 3.3932| Val loss: 3.6691
# No improvement for 2 epoch(s)
# Epoch: 181| Train loss: 3.3868| Val loss: 3.6937
# No improvement for 3 epoch(s)
# Epoch: 182| Train loss: 3.3750| Val loss: 3.6681
# No improvement for 4 epoch(s)
# Epoch: 183| Train loss: 3.3690| Val loss: 3.6562
# No improvement for 5 epoch(s)
# Epoch: 184| Train loss: 3.3587| Val loss: 3.6417
# Metric improved to 3.6417. Checkpoint saved at epoch 183
# Epoch: 185| Train loss: 3.3513| Val loss: 3.6494
# No improvement for 1 epoch(s)
# Epoch: 186| Train loss: 3.3426| Val loss: 3.5615
# Metric improved to 3.5615. Checkpoint saved at epoch 185
# Epoch: 187| Train loss: 3.3338| Val loss: 3.5709
# No improvement for 1 epoch(s)
# Epoch: 188| Train loss: 3.3251| Val loss: 3.5878
# No improvement for 2 epoch(s)
# Epoch: 189| Train loss: 3.3188| Val loss: 3.5600
# Metric improved to 3.5600. Checkpoint saved at epoch 188
# Epoch: 190| Train loss: 3.3103| Val loss: 3.5484
# Metric improved to 3.5484. Checkpoint saved at epoch 189
# Epoch: 191| Train loss: 3.3041| Val loss: 3.5981
# No improvement for 1 epoch(s)
# Epoch: 192| Train loss: 3.2988| Val loss: 3.6185
# No improvement for 2 epoch(s)
# Epoch: 193| Train loss: 3.2889| Val loss: 3.5970
# No improvement for 3 epoch(s)
# Epoch: 194| Train loss: 3.2859| Val loss: 3.5531
# No improvement for 4 epoch(s)
# Epoch: 195| Train loss: 3.2811| Val loss: 3.6326
# No improvement for 5 epoch(s)
# Epoch: 196| Train loss: 3.2917| Val loss: 3.5522
# No improvement for 6 epoch(s)
# Epoch: 197| Train loss: 3.2645| Val loss: 3.4793
# Metric improved to 3.4793. Checkpoint saved at epoch 196
# Epoch: 198| Train loss: 3.2607| Val loss: 3.4932
# No improvement for 1 epoch(s)
# Epoch: 199| Train loss: 3.2605| Val loss: 3.4954
# No improvement for 2 epoch(s)
# Epoch: 200| Train loss: 3.2590| Val loss: 3.4866
# No improvement for 3 epoch(s)
# Epoch: 201| Train loss: 3.2585| Val loss: 3.4983
# No improvement for 4 epoch(s)
# Epoch: 202| Train loss: 3.2573| Val loss: 3.4895
# No improvement for 5 epoch(s)
# Epoch: 203| Train loss: 3.2566| Val loss: 3.4860
# No improvement for 6 epoch(s)
# Epoch: 204| Train loss: 3.2561| Val loss: 3.4863
# No improvement for 7 epoch(s)
# Epoch: 205| Train loss: 3.2560| Val loss: 3.4879
# No improvement for 8 epoch(s)
# Epoch: 206| Train loss: 3.2559| Val loss: 3.4890
# No improvement for 9 epoch(s)
# Epoch: 207| Train loss: 3.2558| Val loss: 3.4902
# No improvement for 10 epoch(s)
# Epoch: 208| Train loss: 3.2557| Val loss: 3.4905
# No improvement for 11 epoch(s)
# Epoch: 209| Train loss: 3.2557| Val loss: 3.4911
# No improvement for 12 epoch(s)
# Epoch: 210| Train loss: 3.2556| Val loss: 3.4909
# No improvement for 13 epoch(s)
# Epoch: 211| Train loss: 3.2556| Val loss: 3.4908
# No improvement for 14 epoch(s)
# Epoch: 212| Train loss: 3.2556| Val loss: 3.4909
# No improvement for 15 epoch(s)
# Epoch: 213| Train loss: 3.2556| Val loss: 3.4909
# No improvement for 16 epoch(s)
# Epoch: 214| Train loss: 3.2556| Val loss: 3.4908
# No improvement for 17 epoch(s)
# Epoch: 215| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 18 epoch(s)
# Epoch: 216| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 19 epoch(s)
# Epoch: 217| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 20 epoch(s)
# Epoch: 218| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 21 epoch(s)
# Epoch: 219| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 22 epoch(s)
# Epoch: 220| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 23 epoch(s)
# Epoch: 221| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 24 epoch(s)
# Epoch: 222| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 25 epoch(s)
# Epoch: 223| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 26 epoch(s)
# Epoch: 224| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 27 epoch(s)
# Epoch: 225| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 28 epoch(s)
# Epoch: 226| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 29 epoch(s)
# Epoch: 227| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 30 epoch(s)
# Epoch: 228| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 31 epoch(s)
# Epoch: 229| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 32 epoch(s)
# Epoch: 230| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 33 epoch(s)
# Epoch: 231| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 34 epoch(s)
# Epoch: 232| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 35 epoch(s)
# Epoch: 233| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 36 epoch(s)
# Epoch: 234| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 37 epoch(s)
# Epoch: 235| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 38 epoch(s)
# Epoch: 236| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 39 epoch(s)
# Epoch: 237| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 40 epoch(s)
# Epoch: 238| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 41 epoch(s)
# Epoch: 239| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 42 epoch(s)
# Epoch: 240| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 43 epoch(s)
# Epoch: 241| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 44 epoch(s)
# Epoch: 242| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 45 epoch(s)
# Epoch: 243| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 46 epoch(s)
# Epoch: 244| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 47 epoch(s)
# Epoch: 245| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 48 epoch(s)
# Epoch: 246| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 49 epoch(s)
# Epoch: 247| Train loss: 3.2556| Val loss: 3.4907
# No improvement for 50 epoch(s)
# Early stopping triggered after 50 epochs of no improvement
# Restored best model and optimizer states from checkpoint
# Stopping at epoch  246

# %%
# perform evaluation on the test dataset using the l1 loss

l1_loss = nn.L1Loss(reduction='mean')
loss_ = []

with torch.no_grad():
    seq2seq.eval()
    for x_batch, y_batch in test_dl:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        out = seq2seq(x_batch)
        loss = l1_loss(out, y_batch)
        loss_.append(loss.item())
        break

# %%
(sum(loss_)/len(loss_)) * 1e6
# Out:
# 198735.3265285492

# %%
rail_valid
# Out:
# date
# 2019-01-01    0.245852
# 2019-01-02    0.573542
# 2019-01-03    0.627781
# 2019-01-04    0.628514
# 2019-01-05    0.348257
#                 ...
# 2019-05-27    0.256757
# 2019-05-28    0.694292
# 2019-05-29    0.717681
# 2019-05-30    0.735508
# 2019-05-31    0.738322
# Name: rail, Length: 151, dtype: float64

# %%
pred_set = torch.tensor(rail_test.iloc[:56].values.tolist(), device=device).reshape(1,56,1)

# %%
with torch.no_grad():
    prediction = seq2seq(pred_set)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,5))
ax.plot(rail_test.iloc[56:56+14],label='truth')
ax.plot(
    pd.Series(
    prediction[-1, -1, :].detach().cpu().numpy(),
    index = rail_test.iloc[56:56+14].index
),label='pred'
)
ax.legend()

# %%
prediction[-1, -1, :].detach().cpu().numpy().shape
# Out:
# (14,)

# %%
pd.Series(
    prediction[-1, -1, :].detach().cpu().numpy(),
    index = rail_valid.iloc[56:56+14].index
)
# Out:
# date
# 2019-02-26    0.709984
# 2019-02-27    0.729437
# 2019-02-28    0.742834
# 2019-03-01    0.694376
# 2019-03-02    0.390395
# 2019-03-03    0.273050
# 2019-03-04    0.637456
# 2019-03-05    0.712779
# 2019-03-06    0.750573
# 2019-03-07    0.757194
# 2019-03-08    0.718573
# 2019-03-09    0.380624
# 2019-03-10    0.296695
# 2019-03-11    0.663787
# dtype: float32
