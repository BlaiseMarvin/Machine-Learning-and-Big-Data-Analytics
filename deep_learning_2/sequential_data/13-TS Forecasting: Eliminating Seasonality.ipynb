# %% [markdown]
# Building on previous notebook:
# - Qn: Does eliminating seasonality

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, Subset
import matplotlib.pyplot as plt
from utils.fetch_data import fetch_timeseries_data
from utils.load_data import TimeSeriesDataset
from utils.early_stopping import EarlyStopping
from utils.fetch_data import create_splits

# %%
torch.manual_seed(1)

# %% [markdown]
# Get the data:

# %%
df = fetch_timeseries_data()

# create the training, validation, and test splits:
rail_train, rail_valid, rail_test = create_splits(df, attr='rail', train_ran=['2016-01','2024-12'],val_ran=['2025-01','2025-04'],test_ran=['2025-05'])

# %% [markdown]
# Seasonality exploration:

# %% [markdown]
# Search for weekly seasonality:
# - plot out a week's worth of data and see if there's anything repeating itself

# %%
rail_train['2024-01':'2024-05'].plot(grid=True, marker='.', figsize=(10,3.5))
plt.show()

# %%
rail_train['2023-01':'2023-05'].plot(grid=True, marker='.', figsize=(10,3.5))
plt.show()

# %%
rail_train['2023-01'].plot(grid=True, marker='.', figsize=(10,3.5))
plt.show()

# %%
rail_train['2023-02'].plot(grid=True, marker='.', figsize=(10,3.5))
plt.show()

# %% [markdown]
# There's weekly seasonality- starts low at the start of the week, then peaks midweek before dipping again and repeating the cycle the following week.

# %%
rail_train[:10]
# Out:
# date
# 2016-01-01    0.319835
# 2016-01-02    0.365509
# 2016-01-03    0.287661
# 2016-01-04    0.703185
# 2016-01-05    0.727716
# 2016-01-06    0.733167
# 2016-01-07    0.736809
# 2016-01-08    0.732495
# 2016-01-09    0.391597
# 2016-01-10    0.263073
# Name: rail, dtype: float64

# %%
rail_train.diff(7)[:10]
# Out:
# date
# 2016-01-01         NaN
# 2016-01-02         NaN
# 2016-01-03         NaN
# 2016-01-04         NaN
# 2016-01-05         NaN
# 2016-01-06         NaN
# 2016-01-07         NaN
# 2016-01-08    0.412660
# 2016-01-09    0.026088
# 2016-01-10   -0.024588
# Name: rail, dtype: float64

# %% [markdown]
# eliminating the weekly seasonality by subtracting today's value from last 7 days' value - should result in a flatter curve without seasonality:

# %%
fig, axs = plt.subplots(2, 1, sharex=True, figsize=(20,10))
rail_train.iloc[:100].plot(ax=axs[0], legend=False, marker='.') # original time series
rail_train.iloc[:100].shift(7).plot(ax=axs[0], grid=True, legend=False, linestyle=':') # lagged 
rail_train.iloc[:100].diff(7).plot(ax=axs[1], grid=True, marker='.') # 7 day difference time series
plt.show()

# %%
# rail train values with weekly seasonality eliminated:
rail_train_se = rail_train.diff(7)

# %%
period = slice("2016","2024")

rt_monthly = rail_train.resample('ME').mean() # compute the mean for each month
rolling_average_12_months = rt_monthly[period].rolling(window=12).mean()

fig, ax = plt.subplots(figsize=(8,4))
rt_monthly[period].plot(ax=ax, marker='.')
rolling_average_12_months.plot(ax=ax, grid=True, legend=False)
plt.show()

# %%
period = slice("2016","2024")

rt_monthly = rail_train_se.resample('ME').mean() # compute the mean for each month
rolling_average_12_months = rt_monthly[period].rolling(window=12).mean()

fig, ax = plt.subplots(figsize=(8,4))
rt_monthly[period].plot(ax=ax, marker='.')
rolling_average_12_months.plot(ax=ax, grid=True, legend=False)
plt.show()

# %% [markdown]
# No long term trends in the rail_train_monthly_se with weekly seasonality removed.

# %% [markdown]
# Using the weekly seasonality removal as a preprocessing step and applying this to both the train, validation, and test data - retraining the model and observing the changes in performance.

# %%
def eliminate_seasonality(data):
    data = data.diff(7)
    return data.iloc[7:]

# %%
def original_series(diff_data, truth):
    truth_shifted = truth.shift(7).iloc[7:]
    return truth_shifted + diff_data

# %% [markdown]
# Process the data

# %%
rail_train_p, rail_valid_p, rail_test_p = eliminate_seasonality(rail_train), eliminate_seasonality(rail_valid), eliminate_seasonality(rail_test)

# %% [markdown]
# Creating chunks:
# - chunks for a sequence to sequence model that forecasts 14 days ahead.

# %%
seq_length = 56
forecasting_horizon = 14

def create_x_chunks(ds):
    return [ds[i:i+seq_length] for i in range(len(ds)-seq_length-forecasting_horizon+1)]

def create_y_chunks(ds):
    y_chunks = []
    for i in range(len(ds)-seq_length-forecasting_horizon+1):
        seq_chunk = [ds[i+j+1:i+j+1+forecasting_horizon] for j in range(seq_length)] # for each element in the sequence, get the next 14 values
        y_chunks.append(seq_chunk)
    return y_chunks

# %%
train_x_chunks, train_y_chunks = create_x_chunks(rail_train_p.values.tolist()), create_y_chunks(rail_train_p.values.tolist())
valid_x_chunks, valid_y_chunks = create_x_chunks(rail_valid_p.values.tolist()), create_y_chunks(rail_valid_p.values.tolist())
test_x_chunks, test_y_chunks = create_x_chunks(rail_test_p.values.tolist()), create_y_chunks(rail_test_p.values.tolist())

# %%
train_x_chunks, train_y_chunks = torch.tensor(train_x_chunks), torch.tensor(train_y_chunks)
valid_x_chunks, valid_y_chunks = torch.tensor(valid_x_chunks), torch.tensor(valid_y_chunks)
test_x_chunks, test_y_chunks = torch.tensor(test_x_chunks), torch.tensor(test_y_chunks)

# %%
train_x_chunks.shape, train_y_chunks.shape
# Out:
# (torch.Size([3212, 56]), torch.Size([3212, 56, 14]))

# %%
train_x_chunks[3211,:]
# Out:
# tensor([-0.0007, -0.0010, -0.0046, -0.0578, -0.0238, -0.0144, -0.0072, -0.0096,
#         -0.0395, -0.0271, -0.0150,  0.0123, -0.0061, -0.0656, -0.0239,  0.0251,
#          0.0145,  0.0076,  0.0045, -0.0246,  0.0588,  0.0064, -0.0111,  0.0007,
#          0.0275,  0.0013,  0.0245,  0.0018, -0.0054, -0.0251,  0.0344,  0.0246,
#         -0.0117, -0.0384, -0.0829, -0.1200, -0.2821, -0.2068, -0.1234, -0.0468,
#          0.0045,  0.0491,  0.1021,  0.2692,  0.1469,  0.0688,  0.0411,  0.0151,
#          0.0004, -0.0130, -0.0507, -0.0108, -0.0236, -0.0183, -0.0217, -0.0150])

# %%
train_y_chunks[3211,54,:]
# Out:
# tensor([-0.0150, -0.0157,  0.0229, -0.0341, -0.0284, -0.0097, -0.0748, -0.2098,
#         -0.2960, -0.1485, -0.0812, -0.0115, -0.0296,  0.0177])

# %% [markdown]
# Logical checks above are good... lets now create the dataset that will enable batching

# %%
class TsDataset(Dataset):
    def __init__(self, x_chunks, y_chunks):
        super().__init__()
        self.x_chunks = x_chunks.unsqueeze(2)
        self.y_chunks = y_chunks
    def __len__(self):
        return self.x_chunks.shape[0]
    def __getitem__(self, index):
        x,y = self.x_chunks[index,:,:], self.y_chunks[index,:,:]
        return x,y

# %%
train_ds = TsDataset(train_x_chunks, train_y_chunks)
val_ds = TsDataset(valid_x_chunks, valid_y_chunks)
test_ds = TsDataset(test_x_chunks, test_y_chunks)

# %%
train_dl = DataLoader(train_ds, batch_size=128, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=128)
test_dl = DataLoader(test_ds, batch_size=1024)

# %% [markdown]
# Model building:
# - Using the same simple LSTM as last time

# %%
torch.manual_seed(1)

# %%
class CustomLSTMCell(nn.Module):
    def __init__(self, input_size, hidden_size, device):
        super().__init__()
        self.input = nn.Linear(input_size, 4*hidden_size,device=device) # instead of breaking this down, could just compute these with one linear layer and break down its results later
        nn.init.xavier_uniform_(self.input.weight.data)
        self.hidden = nn.Linear(hidden_size, 4*hidden_size,device=device) # same for this
        nn.init.xavier_uniform_(self.hidden.weight.data)
        nn.init.zeros_(self.input.bias)
        nn.init.zeros_(self.hidden.bias)

        self.hidden_size = hidden_size
        self.ln_gates = nn.LayerNorm(4*hidden_size,device=device)
        self.ln_c = nn.LayerNorm(hidden_size, device=device)
        self.device = device
    def forward(self, x, prev_h, prev_c):
        computed_inputs = self.input(x)
        computed_hiddens = self.hidden(prev_h)

        gates = self.ln_gates(computed_inputs+computed_hiddens)

        # compute the input gate
        input_gate = torch.sigmoid(gates[:,:self.hidden_size])
        forget_gate = torch.sigmoid(gates[:,self.hidden_size:2*self.hidden_size])
        signal = torch.tanh(gates[:,2*self.hidden_size:3*self.hidden_size])
        output_gate = torch.sigmoid(gates[:,3*self.hidden_size:4*self.hidden_size])
        long_state = forget_gate*prev_c + input_gate*signal
        return output_gate*torch.tanh(self.ln_c(long_state)), long_state

# %%
class CustomLSTMLayer(nn.Module):
    def __init__(self, input_size, hidden_size, device):
        super().__init__()
        self.lstm_cell = CustomLSTMCell(input_size, hidden_size,device)
        self.hidden_size = hidden_size
        self.device = device
    def forward(self, input):
        batch, seq_len, _ = input.shape
        short_term_state = []
        long_term_state = []
        prev_h = torch.zeros((batch, self.hidden_size), device=self.device)
        prev_c = torch.zeros((batch, self.hidden_size), device= self.device)

        for i in range(seq_len):
            xt = input[:,i,:]
            prev_h, prev_c = self.lstm_cell(xt, prev_h, prev_c)
            short_term_state.append(prev_h)
            long_term_state.append(prev_c)
        out = torch.stack(short_term_state, dim=1)
        return out, (prev_h,  prev_c)

# %%
torch.manual_seed(1)

# %%
class Seq2SeqUnivar(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, device):
        super().__init__()
        #self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True, num_layers=1)
        self.lstm = CustomLSTMLayer(input_size, hidden_size1,device)
        self.lstm2 = CustomLSTMLayer(hidden_size1, hidden_size2,device)
        #nn.init.xavier_uniform_(self.lstm.weight_ih_l0.data)
        #nn.init.xavier_uniform_(self.lstm.weight_hh_l0.data)
        self.linear = nn.Linear(hidden_size2, 64)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(64,32)
        self.linear3 = nn.Linear(32,14)
        self.ln = nn.LayerNorm(128)
        self.ln2 = nn.LayerNorm(64)
        self.ln3 = nn.LayerNorm(32)
        self.ln
    def forward(self, input):
        out, (_,_) = self.lstm(input)
        out, (_,_) = self.lstm2(out)
        out = self.ln(out)
        out = self.relu(self.ln2(self.linear(out)))
        out = self.relu(self.ln3(self.linear2(out)))
        return self.linear3(out)

# %%
device = torch.device("mps" if torch.mps.is_available() else "cpu")

# %%
model = Seq2SeqUnivar(1, 512, 128, device=device).to(device)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.002)
criterion = nn.HuberLoss(reduction='sum')
early_stopper = EarlyStopping(patience=50, checkpoint_path='seq2seqx.pt', restore_best_weights=True, verbose=True)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',patience=10, factor=0.9)

# %%
n_epochs = 1000

train_loss = [0] * n_epochs
val_loss = [0] * n_epochs

for epoch in range(n_epochs):
    model.train()
    # iterate through the training data
    for x_batch, y_batch in train_dl:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        out = model(x_batch)
        # adding l1 norm
        norm = sum(p.abs().sum() for p in model.parameters())
        loss = criterion(out, y_batch) + 1e-3*norm
        loss.backward()
        #torch.nn.utils.clip_grad_norm_(model.parameters(), 2.0)
        optimizer.step()
        train_loss[epoch]+=loss.item()
    train_loss[epoch] /= len(train_dl.dataset)

    model.eval()
    with torch.no_grad():
        for x_batch,y_batch in val_dl:
            x_batch,y_batch = x_batch.to(device),y_batch.to(device)
            out = model(x_batch)
            loss = criterion(out, y_batch)
            val_loss[epoch] += loss.item()
        val_loss[epoch] /= len(val_dl.dataset)

        scheduler.step(val_loss[epoch])
        print(f'Epoch: {epoch+1}| Train loss: {train_loss[epoch]:.4f}| Val loss: {val_loss[epoch]:.4f}')
        early_stopper(val_loss[epoch], model, optimizer, epoch)
        if early_stopper.should_stop:
            print(f"Stopping at epoch: {epoch+1}")
            break
# Out:
# Epoch: 1| Train loss: 13.1026| Val loss: 1.8754
# Metric improved to 1.8754. Checkpoint saved at epoch 0
# Epoch: 2| Train loss: 2.9678| Val loss: 1.7878
# Metric improved to 1.7878. Checkpoint saved at epoch 1
# Epoch: 3| Train loss: 2.9305| Val loss: 1.7730
# Metric improved to 1.7730. Checkpoint saved at epoch 2
# Epoch: 4| Train loss: 2.9257| Val loss: 1.7780
# No improvement for 1 epoch(s)
# Epoch: 5| Train loss: 2.9248| Val loss: 1.7774
# No improvement for 2 epoch(s)
# Epoch: 6| Train loss: 2.9238| Val loss: 1.7694
# Metric improved to 1.7694. Checkpoint saved at epoch 5
# Epoch: 7| Train loss: 2.9230| Val loss: 1.7694
# Metric improved to 1.7694. Checkpoint saved at epoch 6
# Epoch: 8| Train loss: 2.9224| Val loss: 1.7717
# No improvement for 1 epoch(s)
# Epoch: 9| Train loss: 2.9220| Val loss: 1.7752
# No improvement for 2 epoch(s)
# Epoch: 10| Train loss: 2.9217| Val loss: 1.7776
# No improvement for 3 epoch(s)
# Epoch: 11| Train loss: 2.9215| Val loss: 1.7723
# No improvement for 4 epoch(s)
# Epoch: 12| Train loss: 2.9208| Val loss: 1.7783
# No improvement for 5 epoch(s)
# Epoch: 13| Train loss: 2.9205| Val loss: 1.7844
# No improvement for 6 epoch(s)
# Epoch: 14| Train loss: 2.9218| Val loss: 1.7740
# No improvement for 7 epoch(s)
# Epoch: 15| Train loss: 2.9221| Val loss: 1.7720
# No improvement for 8 epoch(s)
# Epoch: 16| Train loss: 2.9199| Val loss: 1.7690
# Metric improved to 1.7690. Checkpoint saved at epoch 15
# Epoch: 17| Train loss: 2.9196| Val loss: 1.7760
# No improvement for 1 epoch(s)
# Epoch: 18| Train loss: 2.9199| Val loss: 1.7694
# No improvement for 2 epoch(s)
# Epoch: 19| Train loss: 2.9187| Val loss: 1.7663
# Metric improved to 1.7663. Checkpoint saved at epoch 18
# Epoch: 20| Train loss: 2.9184| Val loss: 1.7737
# No improvement for 1 epoch(s)
# Epoch: 21| Train loss: 2.9187| Val loss: 1.7647
# Metric improved to 1.7647. Checkpoint saved at epoch 20
# Epoch: 22| Train loss: 2.9186| Val loss: 1.7715
# No improvement for 1 epoch(s)
# Epoch: 23| Train loss: 2.9180| Val loss: 1.7675
# No improvement for 2 epoch(s)
# Epoch: 24| Train loss: 2.9178| Val loss: 1.7626
# Metric improved to 1.7626. Checkpoint saved at epoch 23
# Epoch: 25| Train loss: 2.9180| Val loss: 1.7614
# Metric improved to 1.7614. Checkpoint saved at epoch 24
# Epoch: 26| Train loss: 2.9175| Val loss: 1.7656
# No improvement for 1 epoch(s)
# Epoch: 27| Train loss: 2.9169| Val loss: 1.7636
# No improvement for 2 epoch(s)
# Epoch: 28| Train loss: 2.9156| Val loss: 1.7600
# Metric improved to 1.7600. Checkpoint saved at epoch 27
# Epoch: 29| Train loss: 2.9160| Val loss: 1.7635
# No improvement for 1 epoch(s)
# Epoch: 30| Train loss: 2.9153| Val loss: 1.7666
# No improvement for 2 epoch(s)
# Epoch: 31| Train loss: 2.9158| Val loss: 1.7648
# No improvement for 3 epoch(s)
# Epoch: 32| Train loss: 2.9151| Val loss: 1.7598
# Metric improved to 1.7598. Checkpoint saved at epoch 31
# Epoch: 33| Train loss: 2.9147| Val loss: 1.7616
# No improvement for 1 epoch(s)
# Epoch: 34| Train loss: 2.9138| Val loss: 1.7724
# No improvement for 2 epoch(s)
# Epoch: 35| Train loss: 2.9132| Val loss: 1.7564
# Metric improved to 1.7564. Checkpoint saved at epoch 34
# Epoch: 36| Train loss: 2.9144| Val loss: 1.7826
# No improvement for 1 epoch(s)
# Epoch: 37| Train loss: 2.9143| Val loss: 1.7636
# No improvement for 2 epoch(s)
# Epoch: 38| Train loss: 2.9113| Val loss: 1.7775
# No improvement for 3 epoch(s)
# Epoch: 39| Train loss: 2.9118| Val loss: 1.7673
# No improvement for 4 epoch(s)
# Epoch: 40| Train loss: 2.9142| Val loss: 1.7725
# No improvement for 5 epoch(s)
# Epoch: 41| Train loss: 2.9098| Val loss: 1.7802
# No improvement for 6 epoch(s)
# Epoch: 42| Train loss: 2.9131| Val loss: 1.7676
# No improvement for 7 epoch(s)
# Epoch: 43| Train loss: 2.9158| Val loss: 1.7559
# Metric improved to 1.7559. Checkpoint saved at epoch 42
# Epoch: 44| Train loss: 2.9089| Val loss: 1.7689
# No improvement for 1 epoch(s)
# Epoch: 45| Train loss: 2.9133| Val loss: 1.8186
# No improvement for 2 epoch(s)
# Epoch: 46| Train loss: 2.9273| Val loss: 1.7637
# No improvement for 3 epoch(s)
# Epoch: 47| Train loss: 2.9073| Val loss: 1.7721
# No improvement for 4 epoch(s)
# Epoch: 48| Train loss: 2.9000| Val loss: 1.7952
# No improvement for 5 epoch(s)
# Epoch: 49| Train loss: 2.8970| Val loss: 1.7432
# Metric improved to 1.7432. Checkpoint saved at epoch 48
# Epoch: 50| Train loss: 2.8986| Val loss: 1.7777
# No improvement for 1 epoch(s)
# Epoch: 51| Train loss: 2.9090| Val loss: 1.7959
# No improvement for 2 epoch(s)
# Epoch: 52| Train loss: 2.8885| Val loss: 1.8261
# No improvement for 3 epoch(s)
# Epoch: 53| Train loss: 2.9709| Val loss: 1.7595
# No improvement for 4 epoch(s)
# Epoch: 54| Train loss: 2.9057| Val loss: 1.7717
# No improvement for 5 epoch(s)
# Epoch: 55| Train loss: 2.8924| Val loss: 1.7701
# No improvement for 6 epoch(s)
# Epoch: 56| Train loss: 2.8771| Val loss: 1.7563
# No improvement for 7 epoch(s)
# Epoch: 57| Train loss: 2.8904| Val loss: 1.7893
# No improvement for 8 epoch(s)
# Epoch: 58| Train loss: 2.8725| Val loss: 1.7953
# No improvement for 9 epoch(s)
# Epoch: 59| Train loss: 2.8620| Val loss: 1.8477
# No improvement for 10 epoch(s)
# Epoch: 60| Train loss: 2.8597| Val loss: 1.9430
# No improvement for 11 epoch(s)
# Epoch: 61| Train loss: 2.8596| Val loss: 1.7801
# No improvement for 12 epoch(s)
# Epoch: 62| Train loss: 2.8360| Val loss: 1.7405
# Metric improved to 1.7405. Checkpoint saved at epoch 61
# Epoch: 63| Train loss: 2.8122| Val loss: 1.7240
# Metric improved to 1.7240. Checkpoint saved at epoch 62
# Epoch: 64| Train loss: 2.7858| Val loss: 1.8693
# No improvement for 1 epoch(s)
# Epoch: 65| Train loss: 2.7523| Val loss: 2.0113
# No improvement for 2 epoch(s)
# Epoch: 66| Train loss: 2.7739| Val loss: 1.7074
# Metric improved to 1.7074. Checkpoint saved at epoch 65
# Epoch: 67| Train loss: 2.7188| Val loss: 1.7038
# Metric improved to 1.7038. Checkpoint saved at epoch 66
# Epoch: 68| Train loss: 2.6955| Val loss: 1.6917
# Metric improved to 1.6917. Checkpoint saved at epoch 67
# Epoch: 69| Train loss: 2.8776| Val loss: 1.7590
# No improvement for 1 epoch(s)
# Epoch: 70| Train loss: 2.8641| Val loss: 1.8049
# No improvement for 2 epoch(s)
# Epoch: 71| Train loss: 3.0341| Val loss: 1.8116
# No improvement for 3 epoch(s)
# Epoch: 72| Train loss: 2.9047| Val loss: 1.7571
# No improvement for 4 epoch(s)
# Epoch: 73| Train loss: 2.8933| Val loss: 1.7564
# No improvement for 5 epoch(s)
# Epoch: 74| Train loss: 2.8843| Val loss: 1.7548
# No improvement for 6 epoch(s)
# Epoch: 75| Train loss: 2.8640| Val loss: 1.7388
# No improvement for 7 epoch(s)
# Epoch: 76| Train loss: 2.8416| Val loss: 1.8134
# No improvement for 8 epoch(s)
# Epoch: 77| Train loss: 2.7720| Val loss: 1.6885
# Metric improved to 1.6885. Checkpoint saved at epoch 76
# Epoch: 78| Train loss: 2.8409| Val loss: 1.7769
# No improvement for 1 epoch(s)
# Epoch: 79| Train loss: 2.7300| Val loss: 1.6915
# No improvement for 2 epoch(s)
# Epoch: 80| Train loss: 2.6645| Val loss: 1.8065
# No improvement for 3 epoch(s)
# Epoch: 81| Train loss: 2.6374| Val loss: 1.6574
# Metric improved to 1.6574. Checkpoint saved at epoch 80
# Epoch: 82| Train loss: 2.6109| Val loss: 1.6812
# No improvement for 1 epoch(s)
# Epoch: 83| Train loss: 2.5929| Val loss: 1.8031
# No improvement for 2 epoch(s)
# Epoch: 84| Train loss: 2.5695| Val loss: 1.7583
# No improvement for 3 epoch(s)
# Epoch: 85| Train loss: 2.5187| Val loss: 1.6820
# No improvement for 4 epoch(s)
# Epoch: 86| Train loss: 2.4953| Val loss: 1.6812
# No improvement for 5 epoch(s)
# Epoch: 87| Train loss: 2.4588| Val loss: 1.7101
# No improvement for 6 epoch(s)
# Epoch: 88| Train loss: 2.4255| Val loss: 1.6669
# No improvement for 7 epoch(s)
# Epoch: 89| Train loss: 2.4463| Val loss: 1.6740
# No improvement for 8 epoch(s)
# Epoch: 90| Train loss: 2.3781| Val loss: 1.7513
# No improvement for 9 epoch(s)
# Epoch: 91| Train loss: 2.4024| Val loss: 1.7727
# No improvement for 10 epoch(s)
# Epoch: 92| Train loss: 2.3068| Val loss: 1.8214
# No improvement for 11 epoch(s)
# Epoch: 93| Train loss: 2.3172| Val loss: 1.7761
# No improvement for 12 epoch(s)
# Epoch: 94| Train loss: 2.2690| Val loss: 1.6461
# Metric improved to 1.6461. Checkpoint saved at epoch 93
# Epoch: 95| Train loss: 2.3615| Val loss: 1.7268
# No improvement for 1 epoch(s)
# Epoch: 96| Train loss: 2.2417| Val loss: 1.7308
# No improvement for 2 epoch(s)
# Epoch: 97| Train loss: 2.2696| Val loss: 1.7914
# No improvement for 3 epoch(s)
# Epoch: 98| Train loss: 2.2064| Val loss: 1.6677
# No improvement for 4 epoch(s)
# Epoch: 99| Train loss: 2.1990| Val loss: 1.6956
# No improvement for 5 epoch(s)
# Epoch: 100| Train loss: 2.1212| Val loss: 1.9139
# No improvement for 6 epoch(s)
# Epoch: 101| Train loss: 2.1190| Val loss: 1.6564
# No improvement for 7 epoch(s)
# Epoch: 102| Train loss: 2.1270| Val loss: 1.6447
# Metric improved to 1.6447. Checkpoint saved at epoch 101
# Epoch: 103| Train loss: 2.0756| Val loss: 1.7015
# No improvement for 1 epoch(s)
# Epoch: 104| Train loss: 2.1258| Val loss: 1.7343
# No improvement for 2 epoch(s)
# Epoch: 105| Train loss: 2.2058| Val loss: 1.6172
# Metric improved to 1.6172. Checkpoint saved at epoch 104
# Epoch: 106| Train loss: 2.0420| Val loss: 1.6676
# No improvement for 1 epoch(s)
# Epoch: 107| Train loss: 2.0123| Val loss: 1.6187
# No improvement for 2 epoch(s)
# Epoch: 108| Train loss: 2.0462| Val loss: 1.6884
# No improvement for 3 epoch(s)
# Epoch: 109| Train loss: 1.9903| Val loss: 1.6468
# No improvement for 4 epoch(s)
# Epoch: 110| Train loss: 1.9828| Val loss: 1.7351
# No improvement for 5 epoch(s)
# Epoch: 111| Train loss: 1.9620| Val loss: 1.6532
# No improvement for 6 epoch(s)
# Epoch: 112| Train loss: 1.8462| Val loss: 1.9290
# No improvement for 7 epoch(s)
# Epoch: 113| Train loss: 2.6538| Val loss: 1.7450
# No improvement for 8 epoch(s)
# Epoch: 114| Train loss: 2.4635| Val loss: 1.6079
# Metric improved to 1.6079. Checkpoint saved at epoch 113
# Epoch: 115| Train loss: 2.2692| Val loss: 1.6009
# Metric improved to 1.6009. Checkpoint saved at epoch 114
# Epoch: 116| Train loss: 2.1322| Val loss: 1.6970
# No improvement for 1 epoch(s)
# Epoch: 117| Train loss: 2.0312| Val loss: 1.6832
# No improvement for 2 epoch(s)
# Epoch: 118| Train loss: 2.0671| Val loss: 1.5862
# Metric improved to 1.5862. Checkpoint saved at epoch 117
# Epoch: 119| Train loss: 1.9256| Val loss: 1.5495
# Metric improved to 1.5495. Checkpoint saved at epoch 118
# Epoch: 120| Train loss: 1.7867| Val loss: 1.7361
# No improvement for 1 epoch(s)
# Epoch: 121| Train loss: 1.7893| Val loss: 1.5067
# Metric improved to 1.5067. Checkpoint saved at epoch 120
# Epoch: 122| Train loss: 1.6880| Val loss: 1.7347
# No improvement for 1 epoch(s)
# Epoch: 123| Train loss: 1.7625| Val loss: 1.5966
# No improvement for 2 epoch(s)
# Epoch: 124| Train loss: 1.6598| Val loss: 1.6391
# No improvement for 3 epoch(s)
# Epoch: 125| Train loss: 1.6780| Val loss: 1.7181
# No improvement for 4 epoch(s)
# Epoch: 126| Train loss: 1.5917| Val loss: 1.4714
# Metric improved to 1.4714. Checkpoint saved at epoch 125
# Epoch: 127| Train loss: 1.5298| Val loss: 1.5443
# No improvement for 1 epoch(s)
# Epoch: 128| Train loss: 1.4425| Val loss: 1.5454
# No improvement for 2 epoch(s)
# Epoch: 129| Train loss: 1.4482| Val loss: 1.5439
# No improvement for 3 epoch(s)
# Epoch: 130| Train loss: 1.3807| Val loss: 1.7696
# No improvement for 4 epoch(s)
# Epoch: 131| Train loss: 1.5519| Val loss: 1.8470
# No improvement for 5 epoch(s)
# Epoch: 132| Train loss: 1.4167| Val loss: 1.6372
# No improvement for 6 epoch(s)
# Epoch: 133| Train loss: 1.3314| Val loss: 1.5952
# No improvement for 7 epoch(s)
# Epoch: 134| Train loss: 1.3075| Val loss: 1.5390
# No improvement for 8 epoch(s)
# Epoch: 135| Train loss: 1.3106| Val loss: 1.6517
# No improvement for 9 epoch(s)
# Epoch: 136| Train loss: 1.3179| Val loss: 1.5025
# No improvement for 10 epoch(s)
# Epoch: 137| Train loss: 1.2868| Val loss: 1.6628
# No improvement for 11 epoch(s)
# Epoch: 138| Train loss: 1.2229| Val loss: 1.6552
# No improvement for 12 epoch(s)
# Epoch: 139| Train loss: 1.2076| Val loss: 1.6446
# No improvement for 13 epoch(s)
# Epoch: 140| Train loss: 1.1999| Val loss: 1.6281
# No improvement for 14 epoch(s)
# Epoch: 141| Train loss: 1.2022| Val loss: 1.5892
# No improvement for 15 epoch(s)
# Epoch: 142| Train loss: 1.2139| Val loss: 1.8955
# No improvement for 16 epoch(s)
# Epoch: 143| Train loss: 1.1640| Val loss: 1.7097
# No improvement for 17 epoch(s)
# Epoch: 144| Train loss: 1.1086| Val loss: 1.6211
# No improvement for 18 epoch(s)
# Epoch: 145| Train loss: 1.1065| Val loss: 1.7048
# No improvement for 19 epoch(s)
# Epoch: 146| Train loss: 1.1004| Val loss: 1.6615
# No improvement for 20 epoch(s)
# Epoch: 147| Train loss: 1.0962| Val loss: 1.6166
# No improvement for 21 epoch(s)
# Epoch: 148| Train loss: 1.0907| Val loss: 1.6319
# No improvement for 22 epoch(s)
# Epoch: 149| Train loss: 1.0665| Val loss: 1.6701
# No improvement for 23 epoch(s)
# Epoch: 150| Train loss: 1.1131| Val loss: 1.7228
# No improvement for 24 epoch(s)
# Epoch: 151| Train loss: 1.0453| Val loss: 1.7517
# No improvement for 25 epoch(s)
# Epoch: 152| Train loss: 1.0330| Val loss: 1.7831
# No improvement for 26 epoch(s)
# Epoch: 153| Train loss: 1.0122| Val loss: 1.6359
# No improvement for 27 epoch(s)
# Epoch: 154| Train loss: 1.0313| Val loss: 1.9204
# No improvement for 28 epoch(s)
# Epoch: 155| Train loss: 1.0033| Val loss: 1.6339
# No improvement for 29 epoch(s)
# Epoch: 156| Train loss: 1.0091| Val loss: 1.6492
# No improvement for 30 epoch(s)
# Epoch: 157| Train loss: 1.0315| Val loss: 1.7438
# No improvement for 31 epoch(s)
# Epoch: 158| Train loss: 1.1177| Val loss: 1.6637
# No improvement for 32 epoch(s)
# Epoch: 159| Train loss: 1.0006| Val loss: 1.6371
# No improvement for 33 epoch(s)
# Epoch: 160| Train loss: 0.9983| Val loss: 1.6738
# No improvement for 34 epoch(s)
# Epoch: 161| Train loss: 0.9466| Val loss: 1.5528
# No improvement for 35 epoch(s)
# Epoch: 162| Train loss: 0.9396| Val loss: 1.7000
# No improvement for 36 epoch(s)
# Epoch: 163| Train loss: 0.9620| Val loss: 1.5519
# No improvement for 37 epoch(s)
# Epoch: 164| Train loss: 0.9296| Val loss: 1.5486
# No improvement for 38 epoch(s)
# Epoch: 165| Train loss: 0.9173| Val loss: 1.7922
# No improvement for 39 epoch(s)
# Epoch: 166| Train loss: 0.9133| Val loss: 1.6564
# No improvement for 40 epoch(s)
# Epoch: 167| Train loss: 1.0115| Val loss: 1.5349
# No improvement for 41 epoch(s)
# Epoch: 168| Train loss: 0.9583| Val loss: 1.8304
# No improvement for 42 epoch(s)
# Epoch: 169| Train loss: 0.9773| Val loss: 1.6856
# No improvement for 43 epoch(s)
# Epoch: 170| Train loss: 0.9199| Val loss: 1.6065
# No improvement for 44 epoch(s)
# Epoch: 171| Train loss: 0.9154| Val loss: 1.5993
# No improvement for 45 epoch(s)
# Epoch: 172| Train loss: 0.9033| Val loss: 1.5760
# No improvement for 46 epoch(s)
# Epoch: 173| Train loss: 0.8910| Val loss: 1.5351
# No improvement for 47 epoch(s)
# Epoch: 174| Train loss: 0.8728| Val loss: 1.5645
# No improvement for 48 epoch(s)
# Epoch: 175| Train loss: 0.8723| Val loss: 1.5448
# No improvement for 49 epoch(s)
# Epoch: 176| Train loss: 0.8694| Val loss: 1.6071
# No improvement for 50 epoch(s)
# Early stopping triggered after 50 epochs of no improvement
# Restored best model and optimizer states from checkpoint
# Stopping at epoch: 176

# %%
l1_loss = nn.L1Loss(reduction='mean')
loss_ = []

with torch.no_grad():
    model.eval()
    for x_batch, y_batch in test_dl:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        out = model(x_batch)
        loss = l1_loss(out, y_batch)
        loss_.append(loss.item())
        break

# %%
(sum(loss_)/len(loss_)) * 1e6
# Out:
# 35053.84549498558

# %%
pred_set = torch.tensor(rail_test_p.iloc[:56].values.tolist(), device=device).reshape(1,56,1)

# %%
with torch.no_grad():
    model.eval()
    prediction = model(pred_set)

# %%
def original_series(diff_data, truth):
    truth_shifted = truth.shift(7).iloc[7:]
    return truth_shifted + diff_data

# %%
pred_set_truth = rail_test.diff(7)[7:].iloc[:56] + rail_test.shift(7)[7:].iloc[:56]

# %%
prediction_processed = pd.Series(
    prediction[-1,-1,:].detach().cpu().numpy(),
    index = rail_test_p.iloc[56:56+14].index
) + rail_test.shift(7).iloc[7:].iloc[56:56+14]

# %%
prediction_processed
# Out:
# date
# 2025-07-03    0.469967
# 2025-07-04    0.420435
# 2025-07-05    0.350470
# 2025-07-06    0.313704
# 2025-07-07    0.370252
# 2025-07-08    0.461006
# 2025-07-09    0.447348
# 2025-07-10    0.440137
# 2025-07-11    0.292115
# 2025-07-12    0.342134
# 2025-07-13    0.281724
# 2025-07-14    0.411405
# 2025-07-15    0.453052
# 2025-07-16    0.460160
# dtype: float64

# %%
fig, ax = plt.subplots(1,1,figsize=(10,5))
ax.plot((rail_test_p.iloc[56:56+14] + rail_test.shift(7).iloc[7:].iloc[56:56+14]),label='truth')
ax.plot(prediction_processed,label='pred'
)
ax.legend()

# %% [markdown]
# eliminating the seasonality doesn't result in a huge performance improvement
