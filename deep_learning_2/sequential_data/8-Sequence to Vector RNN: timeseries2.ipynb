# %% [markdown]
# **Forecasting Several Timesteps ahead:**
# - Done - predicting and using the predictions to keep on predicting more values by feeding them back into the model.
# - The second option we've got is to train a rnn to predict the next 14 values in one shot. We can still use a sequence to vector model but it will output 14 values instead of one. We need to change the targets to be vectors containing the next 14 values.

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from utils.early_stopping import EarlyStopping
from utils.fetch_data import create_multidim_chunks2, create_splits_mulvar, train_encoder, transform_split, fetch_timeseries_data
from utils.load_data import TimeSeriesDataset2
from utils.train_model import train_multi_d

# %%
import importlib
import utils.fetch_data as fd
importlib.reload(fd)
transform_split = fd.transform_split

# %% [markdown]
# Fetch the dataset:

# %%
df = fetch_timeseries_data()

# %%
df['2019-03':'2019-05'].plot(grid=True, marker='.',figsize=(10,3.5))
plt.show()

# %%
mulvar_train, mulvar_valid, mulvar_test = create_splits_mulvar(df)

# %%
encoder = train_encoder(mulvar_train) # train onehot encoder

# %%
# get the transformed dataframes
mulvar_train, mulvar_valid, mulvar_test = transform_split(mulvar_train, encoder), transform_split(mulvar_valid, encoder), transform_split(mulvar_test, encoder)

# %%
# create chunks
mv_train_chunks, mv_valid_chunks, mv_test_chunks = create_multidim_chunks2(56, mulvar_train, 14), create_multidim_chunks2(56, mulvar_valid, 14), create_multidim_chunks2(56, mulvar_test, 14)

# %%
torch.manual_seed(1)

# %% [markdown]
# create the datasets

# %%
mv_train_ds = TimeSeriesDataset2(torch.tensor(np.array(mv_train_chunks), dtype=torch.float32), seq_length=56)
mv_valid_ds = TimeSeriesDataset2(torch.tensor(np.array(mv_valid_chunks), dtype=torch.float32), seq_length=56)
mv_test_ds = TimeSeriesDataset2(torch.tensor(np.array(mv_test_chunks), dtype=torch.float32), seq_length=56)

# %%
mv_train_dl = DataLoader(mv_train_ds, batch_size=64, shuffle=True)
mv_valid_dl = DataLoader(mv_valid_ds, batch_size=64)
mv_test_dl = DataLoader(mv_test_ds, batch_size=1024)

# %%
z,y = mv_train_ds[0]

# %%
z.shape
# Out:
# torch.Size([56, 5])

# %%
device = torch.device("mps" if torch.mps.is_available() else "cpu")

# %%
class UnivarModel2(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.linear = nn.Linear(hidden_size, 14)
    
    def forward(self, x):
        out, hn = self.rnn(x)
        return self.linear(hn[-1, :, :])

# %%
torch.manual_seed(1)
univar_model2 = UnivarModel2(5,32).to(device)

# %%
#optimizer = torch.optim.SGD(univar_model.parameters(), lr=0.002, momentum=0.9, nesterov=True)
optimizer = torch.optim.Adam(univar_model2.parameters(), lr=0.02)
criterion = nn.HuberLoss(reduction='sum')
early_stopper = EarlyStopping(patience=50, checkpoint_path = 'univar_model3.pt', restore_best_weights=True, verbose=True)
#cheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.009, epochs=500, steps_per_epoch=len(rail_train_dl))
#scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.85)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',patience=5)

# %%
t_loss, v_loss = train_multi_d(500, univar_model2, mv_train_dl, mv_valid_dl, device, criterion, optimizer, early_stopper, performance_scheduler=scheduler,other_scheduler=None, l1_norm=True, l1_lambda=3.0e-5)
# Out:
# Epoch: 1| Train loss: 0.5905| Val loss: 0.1396
# Metric improved to 0.1396. Checkpoint saved at epoch 0
# Epoch: 2| Train loss: 0.1122| Val loss: 0.0464
# Metric improved to 0.0464. Checkpoint saved at epoch 1
# Epoch: 3| Train loss: 0.0665| Val loss: 0.0320
# Metric improved to 0.0320. Checkpoint saved at epoch 2
# Epoch: 4| Train loss: 0.0557| Val loss: 0.0293
# Metric improved to 0.0293. Checkpoint saved at epoch 3
# Epoch: 5| Train loss: 0.0530| Val loss: 0.0330
# No improvement for 1 epoch(s)
# Epoch: 6| Train loss: 0.0530| Val loss: 0.0293
# No improvement for 2 epoch(s)
# Epoch: 7| Train loss: 0.0514| Val loss: 0.0221
# Metric improved to 0.0221. Checkpoint saved at epoch 6
# Epoch: 8| Train loss: 0.0500| Val loss: 0.0384
# No improvement for 1 epoch(s)
# Epoch: 9| Train loss: 0.0548| Val loss: 0.0304
# No improvement for 2 epoch(s)
# Epoch: 10| Train loss: 0.0522| Val loss: 0.0309
# No improvement for 3 epoch(s)
# Epoch: 11| Train loss: 0.0548| Val loss: 0.0248
# No improvement for 4 epoch(s)
# Epoch: 12| Train loss: 0.0513| Val loss: 0.0214
# Metric improved to 0.0214. Checkpoint saved at epoch 11
# Epoch: 13| Train loss: 0.0507| Val loss: 0.0210
# Metric improved to 0.0210. Checkpoint saved at epoch 12
# Epoch: 14| Train loss: 0.0482| Val loss: 0.0272
# No improvement for 1 epoch(s)
# Epoch: 15| Train loss: 0.0478| Val loss: 0.0245
# No improvement for 2 epoch(s)
# Epoch: 16| Train loss: 0.0487| Val loss: 0.0235
# No improvement for 3 epoch(s)
# Epoch: 17| Train loss: 0.0467| Val loss: 0.0252
# No improvement for 4 epoch(s)
# Epoch: 18| Train loss: 0.0470| Val loss: 0.0225
# No improvement for 5 epoch(s)
# Epoch: 19| Train loss: 0.0467| Val loss: 0.0320
# No improvement for 6 epoch(s)
# Epoch: 20| Train loss: 0.0455| Val loss: 0.0187
# Metric improved to 0.0187. Checkpoint saved at epoch 19
# Epoch: 21| Train loss: 0.0421| Val loss: 0.0183
# Metric improved to 0.0183. Checkpoint saved at epoch 20
# Epoch: 22| Train loss: 0.0416| Val loss: 0.0201
# No improvement for 1 epoch(s)
# Epoch: 23| Train loss: 0.0410| Val loss: 0.0188
# No improvement for 2 epoch(s)
# Epoch: 24| Train loss: 0.0407| Val loss: 0.0186
# No improvement for 3 epoch(s)
# Epoch: 25| Train loss: 0.0407| Val loss: 0.0191
# No improvement for 4 epoch(s)
# Epoch: 26| Train loss: 0.0404| Val loss: 0.0194
# No improvement for 5 epoch(s)
# Epoch: 27| Train loss: 0.0404| Val loss: 0.0195
# No improvement for 6 epoch(s)
# Epoch: 28| Train loss: 0.0401| Val loss: 0.0189
# No improvement for 7 epoch(s)
# Epoch: 29| Train loss: 0.0398| Val loss: 0.0190
# No improvement for 8 epoch(s)
# Epoch: 30| Train loss: 0.0398| Val loss: 0.0191
# No improvement for 9 epoch(s)
# Epoch: 31| Train loss: 0.0398| Val loss: 0.0189
# No improvement for 10 epoch(s)
# Epoch: 32| Train loss: 0.0398| Val loss: 0.0192
# No improvement for 11 epoch(s)
# Epoch: 33| Train loss: 0.0398| Val loss: 0.0191
# No improvement for 12 epoch(s)
# Epoch: 34| Train loss: 0.0398| Val loss: 0.0191
# No improvement for 13 epoch(s)
# Epoch: 35| Train loss: 0.0398| Val loss: 0.0191
# No improvement for 14 epoch(s)
# Epoch: 36| Train loss: 0.0398| Val loss: 0.0191
# No improvement for 15 epoch(s)
# Epoch: 37| Train loss: 0.0398| Val loss: 0.0191
# No improvement for 16 epoch(s)
# Epoch: 38| Train loss: 0.0398| Val loss: 0.0191
# No improvement for 17 epoch(s)
# Epoch: 39| Train loss: 0.0398| Val loss: 0.0191
# No improvement for 18 epoch(s)
# Epoch: 40| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 19 epoch(s)
# Epoch: 41| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 20 epoch(s)
# Epoch: 42| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 21 epoch(s)
# Epoch: 43| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 22 epoch(s)
# Epoch: 44| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 23 epoch(s)
# Epoch: 45| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 24 epoch(s)
# Epoch: 46| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 25 epoch(s)
# Epoch: 47| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 26 epoch(s)
# Epoch: 48| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 27 epoch(s)
# Epoch: 49| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 28 epoch(s)
# Epoch: 50| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 29 epoch(s)
# Epoch: 51| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 30 epoch(s)
# Epoch: 52| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 31 epoch(s)
# Epoch: 53| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 32 epoch(s)
# Epoch: 54| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 33 epoch(s)
# Epoch: 55| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 34 epoch(s)
# Epoch: 56| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 35 epoch(s)
# Epoch: 57| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 36 epoch(s)
# Epoch: 58| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 37 epoch(s)
# Epoch: 59| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 38 epoch(s)
# Epoch: 60| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 39 epoch(s)
# Epoch: 61| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 40 epoch(s)
# Epoch: 62| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 41 epoch(s)
# Epoch: 63| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 42 epoch(s)
# Epoch: 64| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 43 epoch(s)
# Epoch: 65| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 44 epoch(s)
# Epoch: 66| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 45 epoch(s)
# Epoch: 67| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 46 epoch(s)
# Epoch: 68| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 47 epoch(s)
# Epoch: 69| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 48 epoch(s)
# Epoch: 70| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 49 epoch(s)
# Epoch: 71| Train loss: 0.0397| Val loss: 0.0191
# No improvement for 50 epoch(s)
# Early stopping triggered after 50 epochs of no improvement
# Restored best model and optimizer states from checkpoint
# Stopping at epoch  70

# %%
l1_loss = nn.L1Loss(reduction='sum')

loss_ = []

with torch.no_grad():
    for x_test_batch, y_test_batch in mv_test_dl:
        x_test_batch = x_test_batch.to(device)
        y_test_batch = y_test_batch.to(device)
        hn = univar_model2(x_test_batch)
        loss = l1_loss(hn, y_test_batch)
        loss_.append(loss.item())

# %%
sum(loss_)/len(mv_test_dl.dataset)*1e6
# Out:
# 2053797.8864082263

# %%
pred_set = mulvar_valid.iloc[-70:-14:,:]

# %%
pred_set.shape
# Out:
# (56, 5)

# %%
with torch.no_grad():
    res = univar_model2(torch.tensor(pred_set.values, dtype=torch.float32, device=device).unsqueeze(0))
    print(res)
# Out:
# tensor([[0.4142, 0.2956, 0.6590, 0.7280, 0.7132, 0.7063, 0.6960, 0.4032, 0.2980,
#          0.6637, 0.7121, 0.7040, 0.7015, 0.6892]], device='mps:0')

# %%
index = mulvar_valid.iloc[-14:,:].index

# %%
index
# Out:
# DatetimeIndex(['2019-05-18', '2019-05-19', '2019-05-20', '2019-05-21',
#                '2019-05-22', '2019-05-23', '2019-05-24', '2019-05-25',
#                '2019-05-26', '2019-05-27', '2019-05-28', '2019-05-29',
#                '2019-05-30', '2019-05-31'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
res_df = pd.DataFrame(
    res.detach().reshape(14,).cpu().numpy(),
    index=index,
    columns=['pred']
)

# %%
fig, ax = plt.subplots(figsize=(10,5))
res_df.plot(kind='line', ax=ax, label='pred')
mulvar_valid.iloc[-14:,1].plot(kind='line', ax=ax,label='truth')
ax.legend()
