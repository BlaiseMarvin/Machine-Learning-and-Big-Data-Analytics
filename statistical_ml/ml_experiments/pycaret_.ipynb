# %%
# load sample dataset
from pycaret.datasets import get_data

# %%
data = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# pycaret has 2 APIs...u can choose one of it based on your preferences...the functionalities and experiment results are consistent..

# %%
# functional API:
from pycaret.classification import *

# %%
s = setup(data, target='Class variable', session_id=123)
# Out:
# <style type="text/css">
# #T_f9c08_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f9c08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9c08_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f9c08_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9c08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9c08_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f9c08_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f9c08_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9c08_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f9c08_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_f9c08_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# **OOP API:**

# %%
from pycaret.classification import ClassificationExperiment

s = ClassificationExperiment()

s.setup(data, target='Class variable', session_id=123)
# Out:
# <style type="text/css">
# #T_3cfe8_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3cfe8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cfe8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3cfe8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cfe8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3cfe8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3cfe8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3cfe8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3cfe8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3cfe8_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_3cfe8_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# **compare models:**
# - this function trains and evaluates the performance of all estimators available in the model library using cross-validation. the output is a scoring grid with the average cross validated scores. metrics evaluated during cv can be accessed using the get_metrics function. custom metrics can be added or removed using the add_metric or remove_metric function.

# %%
# functional api
best = compare_models()
# Out:
# <style type="text/css">
# #T_4e3ac th {
#   text-align: left;
# }
# ...

# %%
# OOP API
best = s.compare_models()
# Out:
# <style type="text/css">
# #T_158c9 th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
s.get_metrics()
# Out:
#                 Name Display Name  \
# ID
# acc         Accuracy     Accuracy
# auc              AUC          AUC
# recall        Recall       Recall
# precision  Precision        Prec.
# f1                F1           F1
# kappa          Kappa        Kappa
# mcc              MCC          MCC
#
#                                               Score Function  \
# ID
# acc                 <function accuracy_score at 0x13e224180>
# auc        <pycaret.internal.metrics.BinaryMulticlassScor...
# recall     <pycaret.internal.metrics.BinaryMulticlassScor...
# precision  <pycaret.internal.metrics.BinaryMulticlassScor...
# f1         <pycaret.internal.metrics.BinaryMulticlassScor...
# kappa            <function cohen_kappa_score at 0x13e224540>
# mcc              <function matthews_corrcoef at 0x13e2247c0>
#
#                                                       Scorer      Target  \
# ID
# acc                                                 accuracy        pred
# ...

# %% [markdown]
# **analyze model**

# %%
# this function analyzes the performance of a trained model on the test set, it may require retraining the model in certain cases///

# %%
s.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# can also use the plot_model function to generate plots individually:

# %%
plot_model(best, plot='auc')

# %% [markdown]
# **predictions:**
# - this fn scores the data and returns prediction_label and prediction_score probability of the predicted class.

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b41cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b41cd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b41cd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b41cd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b41cd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b41cd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b41cd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b41cd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b41cd_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b41cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b41cd_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...

# %% [markdown]
# the above eval metrics are calculated on the test set. the second output is the pd.DataFrame with predictions on the test set. to generate labels on the unseen new dataset...simply pass the dataset in the data parameter under the predict_model function.

# %%
data.head()
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
data.iloc[:,:-2]
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %%
predictions = predict_model(best, data=data.iloc[:,:-1])

# %%
predictions.head()
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# the score from the above dataframe means the probability of the predicted class....(not the positive class). if the prediction label is 0 and prediction score is 0.9 this means 90% probability of class 0.  to see probability of both classes, simply pass raw_score = True in the predict model function

# %%
predictions = predict_model(best, data=data.iloc[:,:-1], raw_score=True)
predictions.head()
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# save the model:

# %%
save_model(best,'my_best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Number of times pregnant',
#                                               'Plasma glucose concentration a 2 '
#                                               'hours in an oral glucose '
#                                               'tolerance test',
#                                               'Diastolic blood pressure (mm Hg)',
#                                               'Triceps skin fold thickness (mm)',
#                                               '2-Hour serum insulin (mu U/ml)',
#                                               'Body mass index (weight in '
#                                               'kg/(height in m)^2)',
#                                               'Diabetes pedigre...
# ...

# %%
boston = get_data('boston')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from pycaret.regression import *

# %%
reg1 = setup(data=boston, target='medv')
# Out:
# <style type="text/css">
# #T_73c67_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_73c67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73c67_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_73c67_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73c67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73c67_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_73c67_row0_col1" class="data row0 col1" >6222</td>
#     </tr>
#     <tr>
#       <th id="T_73c67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73c67_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_73c67_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_73c67_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_a0ae7_row10_col0, #T_a0ae7_row10_col1, #T_a0ae7_row10_col2, #T_a0ae7_row10_col3, #T_a0ae7_row10_col4, #T_a0ae7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a0ae7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0ae7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a0ae7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a0ae7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a0ae7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a0ae7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a0ae7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_dt = tune_model(dt)
# Out:
# <style type="text/css">
# #T_9c6a0_row10_col0, #T_9c6a0_row10_col1, #T_9c6a0_row10_col2, #T_9c6a0_row10_col3, #T_9c6a0_row10_col4, #T_9c6a0_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9c6a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c6a0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9c6a0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9c6a0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9c6a0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9c6a0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9c6a0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
